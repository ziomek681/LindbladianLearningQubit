# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
J = 0 * 10**(-3) * 1.60217663 * 10**(-19) #1meV
dt = 1 * 10**(-14) #0.01ps
Time = 3 * 10**(-12) #10ps

hbar = 1.054571817 * 10**(-34)


NSteps = int(Time/dt)

# %%
t1 = 1 * 10**(-12) #1ps
g1 = 1/t1
L1 = np.array([
    [0,  1],
    [0, 0]
], dtype=complex)*np.sqrt(g1)

# %%
def comutator(A, B):
    return A@B-B@A
def anticomutator(A, B):
    return A@B+B@A
def lindbladOp(L, rho):
    return L @ rho @ np.conj(L.T) - 0.5*anticomutator(np.conj(L.T)@L,rho)

# %%
H = np.array([
    [1,  1],
    [1, -1]
], dtype=complex)*J

psi0 = np.array([0, 1], dtype=complex)
psi0 /= np.linalg.norm(psi0)

rho0 = np.outer(psi0, np.conj(psi0))

print(rho0)
# Out:
# [[0.+0.j 0.+0.j]
#  [0.+0.j 1.+0.j]]

# %%
rho_prev = rho0.copy()
rho_curr = rho0-1j/hbar*dt*comutator(H,rho0)

rho_curr /= np.trace(rho_curr)

times = [0.0, dt]
states = [rho_prev.copy(), rho_curr.copy()]


for i in range(1, NSteps):
    rho_next = rho_prev - 2j/hbar * dt * comutator(H,rho_curr)
    rho_next += 2 * dt * lindbladOp(L1,rho_curr) #Czlony Lindbladowskie
    #print(lindbladOp(L1,rho_curr))

    # normalization (H is hermitian but its discretization might be not!)
    rho_next /= np.trace(rho_next)
    #print(rho_next)

    rho_prev = rho_curr
    rho_curr = rho_next

    times.append((i + 1) * dt)
    states.append(rho_curr.copy())
times = np.array(times)

# %%
# ----------------------------
# Populations
# ----------------------------
states = np.array(states)
pop_0 = np.abs(states[:, 0, 0])
pop_1 = np.abs(states[:, 1, 1])

print(states[NSteps,:,:])

# ----------------------------
# Plot
# ----------------------------
fig, ax = plt.subplots()
ax.plot(times*10**(12), pop_0, label='|0>')
ax.plot(times*10**(12), pop_1, label='|1>')
ax.set_xlabel("t (ps)")
ax.set_ylabel("Populations")
ax.legend()
ax.grid(True)
plt.show()
# Out:
# [[ 1.04987832+0.j  0.        +0.j]
#  [ 0.        +0.j -0.04987832+0.j]]

# %%
Energies = []
for i in range(0, NSteps+1):
    Energies.append(np.trace(H @ states[i,:,:]).real)

Energies = np.array(Energies)

# ----------------------------
# Plot
# ----------------------------
fig, ax = plt.subplots()
ax.plot(times*10**(12), Energies/(1.60217663 * 10**(-19)), label='Energy')
ax.set_xlabel("t (ps)")
ax.set_ylabel("Energy (eV)")
ax.legend()
ax.grid(True)
plt.show()
